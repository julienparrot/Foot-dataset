# %%
### foot.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv("C:\\Users\\julie\\OneDrive\\Bureau\\m1\\s\\SUPPORTS\\data\\foot.csv ", header=0)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  660 non-null    object
#  1   League                   660 non-null    object
#  2   Club                     660 non-null    object
#  3   Player_Names             660 non-null    object
#  4   Matches_Played           660 non-null    int64
#  5   Substitution             660 non-null    int64
#  6   Mins                     660 non-null    int64
#  7   Goals                    660 non-null    int64
#  8   xG                       660 non-null    float64
#  9   xG Per Avg Match         660 non-null    float64
#  10  Shots                    660 non-null    int64
#  11  OnTarget                 660 non-null    int64
#  12  Shots Per Avg Match      660 non-null    float64
#  13  On Target Per Avg Match  660 non-null    float64
# ...

# %%
dataset
# Out:
#           Country      League   Club       Player_Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie   None    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
plt.figure(figsize=(12,7))
sns.countplot(dataset.Goals)
plt.title('Moyenne du nomber de but mis par les joueurs')
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Moyenne du nomber de but mis par les joueurs')

# %%
dataset.drop(dataset.index[(dataset["Goals"] <= 11)],axis=0,inplace=True)

# %%
sns.lmplot(x="Mins", y="Goals", data=dataset)

# %%
sns.distplot(dataset.Mins, bins=20)
plt.title('Moyenne du nombre total de minute jouées par les joueurs')
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Moyenne du nombre total de minute jouées par les joueurs')

# %%
dataset.drop(dataset.index[(dataset["Mins"] <= 2900)],axis=0,inplace=True)

# %%
dataset
# Out:
#      Country                          League    Club  \
# 1      Spain                         La Liga   (BAR)
# 2      Spain                         La Liga   (ATL)
# 12     Spain                         La Liga   (BAR)
# 13     Spain                         La Liga   (VIL)
# 17     Spain                         La Liga  Florin
# ..       ...                             ...     ...
# 454  England                  Premier League   (ARS)
# 456  England                  Premier League   (EVE)
# 461   Brazil  Campeonato Brasileiro SÃ©rie A   (INT)
# 471   Brazil  Campeonato Brasileiro SÃ©rie A    None
# 478   Brazil  Campeonato Brasileiro SÃ©rie A   (CAM)
#
#                   Player_Names  Matches_Played  Substitution   Mins  Goals  \
# 1            Antoine Griezmann              36              0  3129     16
# 2                  Luis Suarez              34              1  2940     28
# 12                Lionel Messi              32              2  2910     37
# ...

# %%
sns.lmplot(x="Shots", y="OnTarget", data=dataset)

# %%
sns.countplot(dataset.Country)
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(dataset.League)
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='League', ylabel='count'>

# %%
dataset.sort_values(by='Goals')
# Out:
#      Country                          League    Club             Player_Names  \
# 128    Italy                         Serie A   (PAR)          Roberto Inglese
# 461   Brazil  Campeonato Brasileiro SÃ©rie A   (INT)          Thiago Galhardo
# 121    Italy                         Serie A   (LAZ)  Sergej Milinkovic-Savic
# 260  England                  Premier League   (CRY)         Luka Milivojevic
# 17     Spain                         La Liga  Florin                  Andone
# ..       ...                             ...     ...                      ...
# 302      USA                             MLS   (ACM)       Zlatan Ibrahimovic
# 107    Spain                         La Liga   (BAR)             Lionel Messi
# 317      USA                             MLS   (LAF)              Carlos Vela
# 391    Italy                         Serie A   (LAZ)            Ciro Immobile
# 12     Spain                         La Liga   (BAR)             Lionel Messi
#
# ...

# %%
dataset.drop(dataset.index[(dataset["Goals"] <= 30)],axis=0,inplace=True)

# %%
dataset.sort_values(by='Goals')
# Out:
#     Country   League   Club        Player_Names  Matches_Played  \
# 302     USA      MLS  (ACM)  Zlatan Ibrahimovic              31
# 385   Italy  Serie A  (JUV)   Cristiano Ronaldo              33
# 107   Spain  La Liga  (BAR)        Lionel Messi              32
# 317     USA      MLS  (LAF)         Carlos Vela              33
# 391   Italy  Serie A  (LAZ)       Ciro Immobile              36
# 12    Spain  La Liga  (BAR)        Lionel Messi              32
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 302              0  2998     31  22.72              0.72    159        67
# 385              0  3127     31  27.32              0.83    208        79
# 107              4  3123     33  32.54              0.99    197        95
# 317              0  3128     36  25.35              0.77    167        75
# 391              1  3371     36  26.61              0.75    142        71
# ...

# %%
dataset.drop(dataset.index[(dataset["League"] == 'MLS')],axis=0,inplace=True)

# %%
dataset.sort_values(by='Goals')
# Out:
#     Country   League   Club       Player_Names  Matches_Played  Substitution   \
# 385   Italy  Serie A  (JUV)  Cristiano Ronaldo              33              0
# 107   Spain  La Liga  (BAR)       Lionel Messi              32              4
# 391   Italy  Serie A  (LAZ)      Ciro Immobile              36              1
# 12    Spain  La Liga  (BAR)       Lionel Messi              32              2
#
#      Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 385  3127     31  27.32              0.83    208        79
# 107  3123     33  32.54              0.99    197        95
# 391  3371     36  26.61              0.75    142        71
# 12   2910     37  26.65              0.87    179        76
#
#      Shots Per Avg Match  On Target Per Avg Match  Year
# 385                 6.32                     2.40  2019
# 107                 5.99                     2.89  2017
# 391                 4.00                     2.00  2019
# ...

# %%
matrix = dataset.corr() 
print(matrix)
# Out:
#                          Matches_Played  Substitution       Mins     Goals  \
# Matches_Played                 1.000000      -0.489762  0.885254  0.239793
# Substitution                  -0.489762       1.000000 -0.255082  0.159473
# Mins                           0.885254      -0.255082  1.000000 -0.105838
# Goals                          0.239793       0.159473 -0.105838  1.000000
# xG                            -0.470623       0.826845 -0.043821 -0.406927
# xG Per Avg Match              -0.827624       0.839274 -0.522408 -0.278405
# Shots                         -0.800703       0.118109 -0.560188 -0.759689
# OnTarget                      -0.649373       0.776224 -0.237716 -0.493064
# Shots Per Avg Match           -0.904961       0.163985 -0.749692 -0.575717
# On Target Per Avg Match       -0.874858       0.761048 -0.571710 -0.362489
# Year                           0.733709      -0.683130  0.811122 -0.464008
#
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(matrix, vmin=0, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x="Matches_Played", y="Goals", data=dataset, linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='Matches_Played', ylabel='Goals'>

# %%
price = dataset[['Player_Names', 'Goals', 'Year']].groupby('Player_Names').median().round(2)
fig, axes = plt.subplots(figsize=(15,5), dpi=100)
plt.bar(price.index, height=price.Goals)
plt.title('Record but dans une saison');

# %%
dataset
# Out:
#     Country   League   Club  Player_Names  Matches_Played  Substitution   \
# 12    Spain  La Liga  (BAR)  Lionel Messi              32              2
# 107   Spain  La Liga  (BAR)  Lionel Messi              32              4
# 195   Spain  La Liga  (BAR)  Lionel Messi              29              5
# 333   Spain  La Liga  (BAR)  Lionel Messi              32              1
# 528   Spain  La Liga  (BAR)  Lionel Messi               8              1
#
#      Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# 12   2910     37  26.65              0.87    179        76
# 107  3123     33  32.54              0.99    197        95
# 195  2849     36  25.49              0.85    170        87
# 333  3067     25  21.63              0.67    159        68
# 528   824      4   5.46              0.63     39        19
#
#      Shots Per Avg Match  On Target Per Avg Match  Year
# 12                  5.84                     2.48  2016
# 107                 5.99                     2.89  2017
# ...

# %%
plt.subplots(figsize=(15,6), dpi=100)
sns.distplot( dataset.loc[dataset.Player_Names=='Lionel Messi', "Goals"] , color="dodgerblue", label="Setosa")
sns.distplot( dataset.loc[dataset.Player_Names=='Cristiano Ronaldo', "Goals"] , color="orange", label="virginica")
sns.distplot( dataset.loc[dataset.Player_Names=='Robert Lewandowski', "Goals"] , color="red", label="virginica")
sns.distplot( dataset.loc[dataset.Player_Names=='Ciro Immobile', "Goals"] , color="pink", label="Ciro Immobile")
sns.distplot( dataset.loc[dataset.Player_Names=='Pierre-Emerick Aubameyang', "Goals"] , color="green", label="Pierre-Emerick Aubameyang")


plt.title('Iris Histogram')
plt.legend();
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
