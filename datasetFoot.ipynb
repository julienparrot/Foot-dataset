# %%
### foot.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv("C:\\Users\\julie\\OneDrive\\Bureau\\m1\\s\\SUPPORTS\\data\\foot.csv ", header=0)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  660 non-null    object
#  1   League                   660 non-null    object
#  2   Club                     660 non-null    object
#  3   Player Names             660 non-null    object
#  4   Matches_Played           660 non-null    int64
#  5   Substitution             660 non-null    int64
#  6   Mins                     660 non-null    int64
#  7   Goals                    660 non-null    int64
#  8   xG                       660 non-null    float64
#  9   xG Per Avg Match         660 non-null    float64
#  10  Shots                    660 non-null    int64
#  11  OnTarget                 660 non-null    int64
#  12  Shots Per Avg Match      660 non-null    float64
#  13  On Target Per Avg Match  660 non-null    float64
# ...

# %%
dataset
# Out:
#           Country      League   Club       Player Names  Matches_Played  \
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 658   Netherlands  Eredivisie   None    Cyriel Dessers               26
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  \
# ...

# %%
plt.figure(figsize=(12,7))
sns.countplot(dataset.Goals)
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Goals', ylabel='count'>

# %%
dataset.drop(dataset.index[(dataset["Goals"] <= 11)],axis=0,inplace=True)

# %%
sns.lmplot(x="Mins", y="Goals", data=dataset)

# %%
sns.distplot(dataset.Mins, bins=20)



dataset.drop(dataset.index[(dataset["Mins"] <= 2900)],axis=0,inplace=True)
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Mins', ylabel='Density'>

# %%
dataset
# Out:
#      Country                          League    Club  \
# 1      Spain                         La Liga   (BAR)
# 2      Spain                         La Liga   (ATL)
# 12     Spain                         La Liga   (BAR)
# 13     Spain                         La Liga   (VIL)
# 17     Spain                         La Liga  Florin
# ..       ...                             ...     ...
# 454  England                  Premier League   (ARS)
# 456  England                  Premier League   (EVE)
# 461   Brazil  Campeonato Brasileiro S̩rie A   (INT)
# 471   Brazil  Campeonato Brasileiro S̩rie A    None
# 478   Brazil  Campeonato Brasileiro S̩rie A   (CAM)
#
#                   Player Names  Matches_Played  Substitution   Mins  Goals  \
# 1            Antoine Griezmann              36              0  3129     16
# 2                  Luis Suarez              34              1  2940     28
# 12                Lionel Messi              32              2  2910     37
# ...

# %%
sns.lmplot(x="Shots", y="OnTarget", data=dataset)

# %%
sns.countplot(dataset.Country)
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(dataset.League)
# Out:
# C:\Users\julie\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='League', ylabel='count'>

# %%
dataset.drop(dataset.index[(dataset["League"] != 'La Liga'':''Serie A')],axis=0,inplace=True)

# %%
dataset.sort_values(by='Goals')
# Out:
#      Country                          League    Club             Player Names  \
# 128    Italy                         Serie A   (PAR)          Roberto Inglese
# 461   Brazil  Campeonato Brasileiro S̩rie A   (INT)          Thiago Galhardo
# 121    Italy                         Serie A   (LAZ)  Sergej Milinkovic-Savic
# 260  England                  Premier League   (CRY)         Luka Milivojevic
# 17     Spain                         La Liga  Florin                  Andone
# ..       ...                             ...     ...                      ...
# 302      USA                             MLS   (ACM)       Zlatan Ibrahimovic
# 107    Spain                         La Liga   (BAR)             Lionel Messi
# 317      USA                             MLS   (LAF)              Carlos Vela
# 391    Italy                         Serie A   (LAZ)            Ciro Immobile
# 12     Spain                         La Liga   (BAR)             Lionel Messi
#
# ...

# %%
dataset.iloc[13,:]
# Out:
# Country                              Italy
# League                             Serie A
# Club                                 (IMI)
# Player Names               Gonzalo Higuain
# Matches_Played                          32
# Substitution                             6
# Mins                                  3138
# Goals                                   24
# xG                                   17.84
# xG Per Avg Match                      0.54
# Shots                                  134
# OnTarget                                91
# Shots Per Avg Match                   4.06
# On Target Per Avg Match               2.75
# Year                                  2016
# Name: 37, dtype: object

# %%
dataset.drop(dataset.index[(dataset["Goals"] <= 30)],axis=0,inplace=True)

# %%
dataset.sort_values(by='Goals')
# Out:
#      Country          League   Club               Player Names  \
# 54   Germany      Bundesliga  (ARS)  Pierre-Emerick Aubameyang
# 302      USA             MLS  (ACM)         Zlatan Ibrahimovic
# 385    Italy         Serie A  (JUV)          Cristiano Ronaldo
# 107    Spain         La Liga  (BAR)               Lionel Messi
# 251   France  France Ligue 1  (PSG)       Kylian Mbappe-Lottin
# 408  Germany      Bundesliga  (BAY)         Robert Lewandowski
# 195    Spain         La Liga  (BAR)               Lionel Messi
# 317      USA             MLS  (LAF)                Carlos Vela
# 391    Italy         Serie A  (LAZ)              Ciro Immobile
# 12     Spain         La Liga  (BAR)               Lionel Messi
#
#      Matches_Played  Substitution   Mins  Goals     xG  xG Per Avg Match  \
# 54               31              1  2894     31  28.94              0.95
# 302              31              0  2998     31  22.72              0.72
# ...

# %%
dataset.drop(dataset.index[(dataset["League"] == 'MLS')],axis=0,inplace=True)

# %%
dataset.sort_values(by='Goals')
# Out:
#      Country          League   Club               Player Names  \
# 54   Germany      Bundesliga  (ARS)  Pierre-Emerick Aubameyang
# 385    Italy         Serie A  (JUV)          Cristiano Ronaldo
# 107    Spain         La Liga  (BAR)               Lionel Messi
# 251   France  France Ligue 1  (PSG)       Kylian Mbappe-Lottin
# 408  Germany      Bundesliga  (BAY)         Robert Lewandowski
# 195    Spain         La Liga  (BAR)               Lionel Messi
# 391    Italy         Serie A  (LAZ)              Ciro Immobile
# 12     Spain         La Liga  (BAR)               Lionel Messi
#
#      Matches_Played  Substitution   Mins  Goals     xG  xG Per Avg Match  \
# 54               31              1  2894     31  28.94              0.95
# 385              33              0  3127     31  27.32              0.83
# 107              32              4  3123     33  32.54              0.99
# 251              24              5  2488     33  31.17              1.19
# ...

# %%
matrix = dataset.corr() 
print(matrix)
# Out:
#                          Matches_Played  Substitution       Mins     Goals  \
# Matches_Played                 1.000000      -0.660973  0.935402  0.161710
# Substitution                  -0.660973       1.000000 -0.434394  0.242065
# Mins                           0.935402      -0.434394  1.000000  0.102846
# Goals                          0.161710       0.242065  0.102846  1.000000
# xG                            -0.353989       0.138162 -0.331103 -0.470246
# xG Per Avg Match              -0.803149       0.355208 -0.816369 -0.339830
# Shots                          0.347939       0.020292  0.439667  0.048260
# OnTarget                       0.088435       0.463931  0.280584 -0.094267
# Shots Per Avg Match           -0.011324       0.224210  0.063356  0.055792
# On Target Per Avg Match       -0.587088       0.777288 -0.435513 -0.138708
# Year                           0.128698      -0.236433  0.182958 -0.012140
#
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(matrix, vmin=0, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,12))
dataset.hist(column='Goals', by='Player Names')
# Out:
# array([[<AxesSubplot:title={'center':'Ciro Immobile'}>,
#         <AxesSubplot:title={'center':'Cristiano Ronaldo'}>],
#        [<AxesSubplot:title={'center':'Kylian Mbappe-Lottin'}>,
#         <AxesSubplot:title={'center':'Lionel Messi'}>],
#        [<AxesSubplot:title={'center':'Pierre-Emerick Aubameyang'}>,
#         <AxesSubplot:title={'center':'Robert Lewandowski'}>]],
#       dtype=object)

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x="Matches_Played", y="Goals", data=dataset, linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='Matches_Played', ylabel='Goals'>

# %%
dataset['Matches_Played']
# Out:
# 1      36
# 2      34
# 12     32
# 13     37
# 17     32
#        ..
# 454    35
# 456    36
# 461    31
# 471    33
# 478    34
# Name: Matches_Played, Length: 113, dtype: int64
